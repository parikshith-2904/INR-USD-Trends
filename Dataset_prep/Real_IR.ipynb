# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Admin\Documents\Codes\Data Analysis Stuff\USD_INR\Dataset_prep\Datasets\real_interest_rate.csv")
df
# Out:
#                     Country Name Country Code          Indicator Name  \
# 0                          Aruba          ABW  Real interest rate (%)
# 1    Africa Eastern and Southern          AFE  Real interest rate (%)
# 2                    Afghanistan          AFG  Real interest rate (%)
# 3     Africa Western and Central          AFW  Real interest rate (%)
# 4                         Angola          AGO  Real interest rate (%)
# ..                           ...          ...                     ...
# 261                       Kosovo          XKX  Real interest rate (%)
# 262                  Yemen, Rep.          YEM  Real interest rate (%)
# 263                 South Africa          ZAF  Real interest rate (%)
# 264                       Zambia          ZMB  Real interest rate (%)
# 265                     Zimbabwe          ZWE  Real interest rate (%)
#
#     Indicator Code  1960      1961      1962      1963      1964      1965  \
# ...

# %%
df = df[df["Country Name"] == "India"] 
df
# Out:
#     Country Name Country Code          Indicator Name Indicator Code  1960  \
# 109        India          IND  Real interest rate (%)    FR.INR.RINR   NaN
#
#      1961  1962  1963  1964  1965  ...      2016      2017      2018  \
# 109   NaN   NaN   NaN   NaN   NaN  ...  6.232711  5.327609  5.361666
#
#          2019   2020      2021      2022  2023  2024  Unnamed: 69
# 109  6.894875  4.136  0.316945  1.704611   NaN   NaN          NaN
#
# [1 rows x 70 columns]

# %%
df = df.T.reset_index()
df
# Out:
#              index                     109
# 0     Country Name                   India
# 1     Country Code                     IND
# 2   Indicator Name  Real interest rate (%)
# 3   Indicator Code             FR.INR.RINR
# 4             1960                     NaN
# ..             ...                     ...
# 65            2021                0.316945
# 66            2022                1.704611
# 67            2023                     NaN
# 68            2024                     NaN
# 69     Unnamed: 69                     NaN
#
# [70 rows x 2 columns]

# %%
df.columns = [["Year","Real interest rate (%)"]]
df
# Out:
#               Year  Real interest rate (%)
# 0     Country Name                   India
# 1     Country Code                     IND
# 2   Indicator Name  Real interest rate (%)
# 3   Indicator Code             FR.INR.RINR
# 4             1960                     NaN
# ..             ...                     ...
# 65            2021                0.316945
# 66            2022                1.704611
# 67            2023                     NaN
# 68            2024                     NaN
# 69     Unnamed: 69                     NaN
#
# [70 rows x 2 columns]

# %%
df = df[4:]
df = df.dropna()
df
# Out:
#     Year Real interest rate (%)
# 22  1978              10.774631
# 23  1979              -1.061146
# 24  1980               4.476508
# 25  1981               5.118237
# 26  1982               7.774707
# 27  1983               7.320987
# 28  1984                 7.9471
# 29  1985               8.681674
# 30  1986               9.093224
# 31  1987                6.56018
# 32  1988               7.638633
# 33  1989               7.435843
# 34  1990               5.269527
# 35  1991               3.624717
# 36  1992               9.132749
# 37  1993               5.814777
# 38  1994                4.33711
# 39  1995               5.864178
# 40  1996               7.792994
# 41  1997               6.909579
# 42  1998               5.121276
# 43  1999               9.191247
# 44  2000               8.342611
# 45  2001               8.591449
# 46  2002               7.907177
# 47  2003               7.307881
# 48  2004               4.910128
# 49  2005               4.855145
# ...

# %%
df.to_csv(r"C:\Users\Admin\Documents\Codes\Data Analysis Stuff\USD_INR\Real_Interest_Rates_IND.csv", index=False)
